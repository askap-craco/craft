# %%
# %matplotlib inline
import numpy as np
from pylab import *

# %%
import craftsim

# %%
f1 = 1200.
nf = 32
f2 = f1 + 8.
npulse = 1.
dm = 2
sn=4
pos=4134567/4
nt=1500
nbins=1500

# %%
x = craftsim.dispersed_stft(f1, f2, nt, nf, nbins, PulseSig=sn)
# Out:
# {'f_max': 1208.0, 'D': 5, 'f_min': 1200.0, 'PulseSig': 4, 'n_samps': 72000000, 'PulsePosition': 1033641, 'n_pulse': 48000}
# MAX Thoretical SNR: 2190.90769179

# %%
imshow(x, aspect='auto', interpolation='nearest')
